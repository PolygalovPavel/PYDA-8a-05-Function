# %% [markdown]
# Вы работаете секретарем и вам постоянно приходят различные документы. Вы должны быть очень внимательны, чтобы не потерять ни один документ. Каталог документов хранится в следующем виде:

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

# %% [markdown]
# Перечень полок, на которых находятся документы хранится в следующем виде:

# %%
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

# %% [markdown]
# Необходимо реализовать пользовательские команды (внимание! это не название функций, которые должны быть выразительными, а команды, которые вводит пользователь, чтобы получить необходимый результат):
#
# - p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;
# - s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится
# Правильно обработайте ситуацию, когда пользователь будет вводить несуществующий документ.
# - l – list – команда, которая выведет список всех документов в формате
# **passport "2207 876234" "Василий Гупкин"**
# - as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень
# - d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок. Предусмотрите сценарий, когда пользователь вводит несуществующий документ;
# - m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую. Корректно обработайте кейсы, когда пользователь пытается переместить несуществующий документ или переместить документ на несуществующую полку;
# - a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться.

# %%
# Набор команд
def comand_p_action(text_doc):
    """
    Команда выдает номер полки по номеру документа при его наличии
    Возвращает String из базы
    """
    check_point = 0
    for line_doc in documents:
        if line_doc['number'] == text_doc:
            result_text = line_doc['name']
            check_point = 1
    if check_point == 1:
        return result_text
    else:
        return f"Номер документа {text_doc} не обнаружен!"
    
    
def comand_s_action(text_doc):
    """
    Команда выдает имя человека по номеру документа при его наличии
    Возвращает String из базы
    """
    check_point = 0
    for line_dir in directories:
        if text_doc in directories[line_dir]:
            result_text = line_dir
            check_point = 1
    if check_point == 1:
        return result_text
    else:
        return f"Номер документа {text_doccomand_text} не обнаружен!"

    
def comand_l_action():
    """
    Команда выводит список всех документов
    Выводит на печать текст построчно в формате "passport "2207 876234" "Василий Гупкин""
    """
    if documents is not None:
        for line_doc in documents:
            print(line_doc['type'] + ' "' + line_doc['number'] + '" "' + line_doc['name'] + '"')
        return
    else:
        return 'База данных пустая!'

    
def comand_as_action(text_dir):
    """
    Команда проверяет имеющие номера полок и при ее отсутствии добавляет ее
    """
    if text_dir in directories.keys():
        return f"Номер полки {text_dir} существует!"
    else:
        directories[text_dir] = []
        return f"Номер полки {text_dir} успешно добавлена!"
    
    
def сomand_d_action(text_doc):
    """
    Команда проверяет наличие документа в базе и среди полок и удаляет его
    """
    result_text = ''
    check_point = 0
    for line_doc in documents:
        if line_doc['number'] == text_doc:
            check_point = 1
            documents.remove(line_doc)
            result_text = f'Документ "{text_doc}" успешно удален из базы'
            for line_dir in directories:
                if text_doc in directories[line_dir]:
                    directories[line_dir].remove(text_doccomand_text)
                    result_text += ' и с полки'
    if check_point == 1:
        return result_text
    else:
        return f"Номер документа {text_doc} отсутствует!"
    
      
def сomand_action_m(text_doc, text_dir):
    """
    Команда проверяет наличие документа на полках и наличе полки, на которую планирует переместить документ
    Если условия выполнены, то удаляет документ с текущей полки и прописывает его на новой полке
    """
    return_text = ''
    check_point = 0
    for line_dir in directories:
        if text_doc in directories[line_dir]:
            if text_dir in directories.keys():
                directories[line_dir].remove(text_doc)
                directories[text_dir].append(text_doc)
                return(f"Документ {text_doc} успешно помещен на полку {text_dir}")
            else:
                return(f"Номер полки {text_dir} отсутствует!")
        else:
            return(f"Номер документа {text_doc} отсутствует!")
        
        
def comand_a_action(text_doc):
    """
    Команда принимает номер документа и проверяет наличие номера документа.
    Если документ есть - выдается сообщение "Даный номер документа существует, измените номер документа".
    Если документа нет - предлагает внесни тип, имя владельца и номер полки.
    Создается запись в документах и списке полок 
    """
    return_text = ''
    if text_doc is not None:
        text_type = input('Введите тип документа: ')
        text_name = input('Введите имя владельца: ')
        text_dir = input('Введите номер полки: ')
        comand_as_action(text_dir)
        documents.append({'type': text_type, 'number': text_doc, 'name': text_name})
        directories[text_dir].append(text_doc)
        return(f"Номер документа {text_doc} внесен в базу")
    else:
        return("Номер документа не внесен!")

# %%
text_comand = ''
comand = input('Введите команду: ')
if comand == ('p'):
    text_doc = input('Введите номер документа для вывода владельца: ')
    print(comand_p_action(text_doc))
elif comand == ('s'):
    text_doc = input('Введите номер документа для вывода номера полки: ')
    print(comand_s_action(text_doc))
elif comand == ('l'):
    comand_l_action()
elif comand == ('as'):
    text_dir = input('Введите номер полки для добавления: ')
    print(comand_as_action(text_dir))
elif comand == ('d'):
    text_doc = input('Введите номер документа для его удаления: ')
    text_info = сomand_d_action(text_doc)
    print(text_info)
elif comand == ('m'):
    text_doc = input('Введите номер документа, который необходимо переместить: ')
    text_dir = input('Введите номер полки, на которую планируете переместить: ')
    print(сomand_action_m(text_doc, text_dir))
elif comand == ('a'):
    text_doc = input('Введите номер документа: ')
    
    print(comand_a_action(text_doc))
else:
    print(f'Команда "{comand}" не корректна!')
# Out:
# Введите команду: l
# passport "2207 876234" "Василий Гупкин"
# invoice "11-2" "Геннадий Покемонов"
# insurance "10006" "Аристарх Павлов"
# test "123 1234" "testovyj"
